# %%
import torch
print(torch.__version__)
print(torch.backends.mps.is_available())
# Out:
# 2.10.0
# True

# %%
import numpy as np

embeddings = np.load("embeddings_2weeks.npy")
print(embeddings.shape)
# Out:
# (119214, 384)
